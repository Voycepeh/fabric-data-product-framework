# %% [markdown]
# # 01 Data sharing agreement — source/agreement-level permission boundary

# %%
# %run 00_env_config

# %%
from datetime import datetime, timezone

from fabricops_kit import register_current_notebook, setup_notebook, write_lakehouse_table

# %% [markdown]
# ## Agreement inputs (source/agreement-level only)

# %%
agreement_id = "r002_sales_demo"
agreement_requested_source = "sales_orders_source"
agreement_source_data_classification = "internal"
agreement_source_contains_pii_flag = False
agreement_source_tables = ["sales_orders"]
agreement_source_stewarding_data_manager_name = "FabricOps steward"
agreement_purpose = "Evaluate source data access for approved FabricOps workflow."
agreement_permitted_uses = "Exploration, profiling, and approved pipeline contract development."
agreement_approval_duration = "12 months"
agreement_approval_date = "2026-01-15"
agreement_requester_name = "FabricOps test requester"
agreement_requesting_department = "Data Platform"
agreement_stewarding_approver_name = "FabricOps data steward"
agreement_stewarding_department = "Data Governance"
agreement_renewal_procedure = "Renewal request must be resubmitted before expiry for steward review."
agreement_status = "approved"
agreement_notes = "Agreement-level boundary only. Table/column governance is handled in later notebooks."

env_name = "dev"
save_to_metadata = False
register_notebook_to_metadata = False

# %%
BOOTSTRAP_01 = setup_notebook(
    config=CONFIG,
    env=env_name,
    required_targets=["metadata"],
    notebook_name="01_da_r002_sales_demo",
)

agreement_name = agreement_requested_source
business_context = agreement_purpose
approved_usage = agreement_permitted_uses
ownership = agreement_source_stewarding_data_manager_name

agreement_record = {
    "agreement_id": agreement_id,
    "agreement_name": agreement_name,
    "business_context": business_context,
    "approved_usage": approved_usage,
    "ownership": ownership,
    "agreement_requested_source": agreement_requested_source,
    "agreement_source_data_classification": agreement_source_data_classification,
    "agreement_source_contains_pii_flag": agreement_source_contains_pii_flag,
    "agreement_source_tables": ",".join(agreement_source_tables),
    "agreement_source_stewarding_data_manager_name": agreement_source_stewarding_data_manager_name,
    "agreement_purpose": agreement_purpose,
    "agreement_permitted_uses": agreement_permitted_uses,
    "agreement_approval_duration": agreement_approval_duration,
    "agreement_approval_date": agreement_approval_date,
    "agreement_requester_name": agreement_requester_name,
    "agreement_requesting_department": agreement_requesting_department,
    "agreement_stewarding_approver_name": agreement_stewarding_approver_name,
    "agreement_stewarding_department": agreement_stewarding_department,
    "agreement_renewal_procedure": agreement_renewal_procedure,
    "agreement_status": agreement_status,
    "agreement_notes": agreement_notes,
    "environment_name": env_name,
    "created_at": datetime.now(timezone.utc).isoformat(),
}

if save_to_metadata:
    agreement_df = spark.createDataFrame([agreement_record])
    write_lakehouse_table(
        agreement_df,
        CONFIG,
        env_name,
        "metadata",
        "METADATA_DATA_AGREEMENT",
        mode="append",
    )
    print("Saved agreement metadata to METADATA_DATA_AGREEMENT.")
else:
    print("Dry run: skipped agreement metadata write.")

# %%
if save_to_metadata and register_notebook_to_metadata:
    register_current_notebook(
        spark,
        metadata_path=CONFIG.path_config.paths[env_name]["metadata"],
        agreement_id=agreement_id,
        notebook_type="01_data_sharing_agreement",
        environment_name=env_name,
    )
    print("Registered notebook in METADATA_NOTEBOOK_REGISTRY.")
else:
    print("Skipped notebook registration.")

# %% [markdown]
# ## Next step
# - `01` captures source/agreement-level approval evidence only.
# - `02` and `03` create and enforce technical evidence under `agreement_id`.
# - `04` (future) handles table/column governance enrichment under `agreement_id + dataset_name + table_name`.
